# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

img = cv.imread('img/person.jpeg', 0)
rows, cols = img.shape

plt.subplot(1, 2, 1)
plt.title("Original")
plt.imshow(img)

M = np.float32([[1, 0.5, 0], [0, 1, 0], [0, 0, 1]])
sheared_img = cv.warpPerspective(img, M, (int(cols * 1.5),
                                            int(rows * 1.5)))

plt.subplot(1, 2, 2)
plt.title("Sheared Image")
plt.imshow(sheared_img)

cv.imwrite('img', sheared_img)
cv.waitKey(0)
#cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[2], line 20
#      17 plt.title("Sheared Image")
#      18 plt.imshow(sheared_img)
# ---> 20 cv.imwrite('img', sheared_img)
#      21 cv.waitKey(0)
#
# error: OpenCV(4.6.0) C:\b\abs_d8ltn27ay8\croot\opencv-suite_1676452046667\work\modules\imgcodecs\src\loadsave.cpp:730: error: (-2:Unspecified error) could not find a writer for the specified extension in function 'cv::imwrite_'
